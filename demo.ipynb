# %%
from datacov import TopoGen

# %%
band_params = {
    'bands': [700, 800, 1800, 2100, 2600],
    'band_probs': [0.5, 1., 0.8, 0.6, 0.5],
    'ue_dist_scale': [0.08, 0.05, 0.04, 0.03, 0.025],
    'ue_dist_loc': [0.2, 0.1, 0.08, 0.06, 0.05]
}
topo = TopoGen(**band_params)
cells, ues = topo.generate_topo()

# %%
cells.head()
# Out:
#        cell_id bs_id az_id  band  azimut    x         y  \
# 0  bs0_az0_700   bs0   az0   700    54.0  0.2  0.800000
# 1  bs0_az1_700   bs0   az1   700   169.0  0.2  0.800000
# 2  bs0_az2_700   bs0   az2   700   279.0  0.2  0.800000
# 3  bs4_az0_700   bs4   az0   700     4.0  0.8  0.635375
# 4  bs4_az1_700   bs4   az1   700   105.0  0.8  0.635375
#
#                                         geometry
# 0  LINESTRING (0.20000 0.80000, 0.31756 0.96180)
# 1  LINESTRING (0.20000 0.80000, 0.00367 0.83816)
# 2  LINESTRING (0.20000 0.80000, 0.23129 0.60246)
# 3  LINESTRING (0.80000 0.63538, 0.99951 0.64933)
# 4  LINESTRING (0.80000 0.63538, 0.74824 0.82856)

# %%
cells.plot('bs_id')
# Out:
# <Axes: >

# %%
ues.head()
# Out:
#        cell_id                                           geometry
# 0  bs0_az0_700  MULTIPOINT (0.36327 1.02824, 0.31526 0.99715, ...
# 1  bs0_az1_700  MULTIPOINT (0.34309 0.94816, 0.17568 1.01175, ...
# 2  bs0_az2_700  MULTIPOINT (0.34335 0.94543, 0.38195 0.90610, ...
# 3  bs0_az0_700  MULTIPOINT (0.01112 0.91663, 0.03299 0.89496, ...
# 4  bs0_az1_700  MULTIPOINT (-0.03751 0.92885, -0.13939 0.80940...

# %%
ues.plot('cell_id')
# Out:
# <Axes: >

# %%
topo.plot_topography()
